# %% [markdown]
# # Setting Up the Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_src = "Datasets/music.csv" #change if needed
df = pd.read_csv(data_src)

df.set_index("Unnamed: 0",inplace = True) 
df.index.name = "Index"

# %%
df.head(5)
# Out:
#          Artist                                        Url_spotify  \
# Index
# 0      Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                                Track  \
# Index
# 0                                     Feel Good Inc.
# 1                                    Rhinestone Eyes
# 2      New Gold (feat. Tame Impala and Bootie Brown)
# 3                                 On Melancholy Hill
# 4                                     Clint Eastwood
#
#                                                Album Album_type  \
# Index
# 0                                         Demon Days      album
# 1                                      Plastic Beach      album
# 2      New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                      Plastic Beach      album
# 4                                           Gorillaz      album
#
#                                         Uri  Danceability  Energy   Key  \
# Index
# 0      spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705   6.0
# 1      spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703   8.0
# 2      spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923   1.0
# 3      spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739   2.0
# 4      spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694  10.0
#
#        Loudness  ...                                  Url_youtube  \
# Index            ...
# 0        -6.679  ...  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1        -5.815  ...  https://www.youtube.com/watch?v=yYDmaexVHic
# 2        -3.930  ...  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3        -5.810  ...  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4        -8.627  ...  https://www.youtube.com/watch?v=1V_xRb0x9aw
#
#                                                    Title   Channel  \
# Index
# 0             Gorillaz - Feel Good Inc. (Official Video)  Gorillaz
# 1      Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz
# 2      Gorillaz - New Gold ft. Tame Impala & Bootie B...  Gorillaz
# 3         Gorillaz - On Melancholy Hill (Official Video)  Gorillaz
# 4             Gorillaz - Clint Eastwood (Official Video)  Gorillaz
#
#              Views      Likes  Comments  \
# Index
# 0      693555221.0  6220896.0  169907.0
# 1       72011645.0  1079128.0   31003.0
# 2        8435055.0   282142.0    7399.0
# 3      211754952.0  1788577.0   55229.0
# 4      618480958.0  6197318.0  155930.0
#
#                                              Description Licensed  \
# Index
# 0      Official HD Video for Gorillaz' fantastic trac...     True
# 1      The official video for Gorillaz - Rhinestone E...     True
# 2      Gorillaz - New Gold ft. Tame Impala & Bootie B...     True
# 3      Follow Gorillaz online:\nhttp://gorillaz.com \...     True
# 4      The official music video for Gorillaz - Clint ...     True
#
#       official_video        Stream
# Index
# 0               True  1.040235e+09
# 1               True  3.100837e+08
# 2               True  6.306347e+07
# 3               True  4.346636e+08
# 4               True  6.172597e+08
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Refining the Dataset for Analysis

# %% [markdown]
# ### 1. Feature Selection

# %% [markdown]
# As seen in a preview of the dataset above, the dataset includes many types of information, such as Spotify metadata, auditory feature measurements, and YouTube video data. While all of these could be explored, **I would like my analysis to focus on the auditory feature data**. These features are numerical, consistently scaled, and have very few missing values, which makes them well-suited for statistical analysis and exploratory data analysis.
#
# In contrast, many of the YouTube-related columns contain missing data. Narrowing the dataset will alow for clearer and more meaningful insights based on what I find the more fascinating to analyze. For this reason, I will **drop columns related to YouTube data** so the analysis can focus on relationships between track-level auditory features.

# %%
youtube_cols = [
    "Url_youtube", "Title", "Channel",
    "Views", "Likes", "Comments",
    "Description", "Licensed", "official_video"
]


df_clean = df.drop(columns=youtube_cols)

# %%
df_clean.head(5)
# Out:
#          Artist                                        Url_spotify  \
# Index
# 0      Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                                Track  \
# Index
# 0                                     Feel Good Inc.
# 1                                    Rhinestone Eyes
# 2      New Gold (feat. Tame Impala and Bootie Brown)
# 3                                 On Melancholy Hill
# 4                                     Clint Eastwood
#
#                                                Album Album_type  \
# Index
# 0                                         Demon Days      album
# 1                                      Plastic Beach      album
# 2      New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                      Plastic Beach      album
# 4                                           Gorillaz      album
#
#                                         Uri  Danceability  Energy   Key  \
# Index
# 0      spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705   6.0
# 1      spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703   8.0
# 2      spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923   1.0
# 3      spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739   2.0
# 4      spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694  10.0
#
#        Loudness  Speechiness  Acousticness  Instrumentalness  Liveness  \
# Index
# 0        -6.679       0.1770      0.008360          0.002330    0.6130
# 1        -5.815       0.0302      0.086900          0.000687    0.0463
# 2        -3.930       0.0522      0.042500          0.046900    0.1160
# 3        -5.810       0.0260      0.000015          0.509000    0.0640
# 4        -8.627       0.1710      0.025300          0.000000    0.0698
#
#        Valence    Tempo  Duration_ms        Stream
# Index
# 0        0.772  138.559     222640.0  1.040235e+09
# 1        0.852   92.761     200173.0  3.100837e+08
# 2        0.551  108.014     215150.0  6.306347e+07
# 3        0.578  120.423     233867.0  4.346636e+08
# 4        0.525  167.953     340920.0  6.172597e+08

# %% [markdown]
# Now this dataset is much cleaner to look at! Let's follow through with cleaning more parts of the dataset.

# %% [markdown]
# ### 2. Handling Null Values

# %% [markdown]
# While we may have gotten rid of the missing Youtube data by removing those features, there are still features with null values. Since I want to utilize all of the auditory features and streaming data later in my analysis, let's remove entries without this information.

# %%
audio_features = [
    "Danceability", "Energy", "Key", "Loudness", "Speechiness",
    "Acousticness", "Instrumentalness", "Liveness", "Valence", "Tempo","Stream"
]

df_clean[audio_features].isna().sum()
# Out:
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Stream              576
# dtype: int64

# %%
df_clean = df_clean.dropna(subset=audio_features)

# %%
df_clean[audio_features].isna().sum()
# Out:
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Stream              0
# dtype: int64

# %% [markdown]
# ### 3. Removing Duplicates
#
# Some songs appear multiple times in this dataset under different artists. To remove them, we can't just remove duplicate track names (as many songs have the same name), so we will remove duplicates that have the same song name as well as identical auditory features, as this means they are true duplicates.

# %%
dup_cols = ["Track"] + audio_features

dup_mask = df_clean.duplicated(subset=dup_cols, keep="first")
print("Duplicate rows to remove:", dup_mask.sum())
dups = df_clean[df_clean.duplicated(subset=dup_cols, keep=False)].sort_values("Track")
dups.head(5)
# Out:
# Duplicate rows to remove: 1660
#                    Artist                                        Url_spotify  \
# Index
# 12749                Coez  https://open.spotify.com/artist/5dXlc7MnpaTeUI...
# 1517               thasup  https://open.spotify.com/artist/19i93sA0D7yS9d...
# 6666   Kris Kristofferson  https://open.spotify.com/artist/0vYQRW5LIDeYQO...
# 4210      Waylon Jennings  https://open.spotify.com/artist/7wCjDgV6nqBsHg...
# 12003        De La Ghetto  https://open.spotify.com/artist/3EiLUeyEcA6fbR...
#
#                                                    Track  \
# Index
# 12749                                   !ly (feat. Coez)
# 1517                                    !ly (feat. Coez)
# 6666   (Ghost) Riders in the Sky - Live at Nassau Col...
# 4210   (Ghost) Riders in the Sky - Live at Nassau Col...
# 12003        1, 2, 3 (feat. Jason Derulo & De La Ghetto)
#
#                          Album Album_type  \
# Index
# 12749       c@ra++ere s?ec!@le      album
# 1517        c@ra++ere s?ec!@le      album
# 6666   Live - American Outlaws      album
# 4210   Live - American Outlaws      album
# 12003            Mal De Amores      album
#
#                                         Uri  Danceability  Energy  Key  \
# Index
# 12749  spotify:track:1E1nbIsPDO1PdtQwsAKKF3         0.765   0.726  7.0
# 1517   spotify:track:1E1nbIsPDO1PdtQwsAKKF3         0.765   0.726  7.0
# 6666   spotify:track:3ST1SVHTxxiGodhUeASN3h         0.553   0.797  2.0
# 4210   spotify:track:3ST1SVHTxxiGodhUeASN3h         0.553   0.797  2.0
# 12003  spotify:track:737gzPI5VAmgUGWiJ9yXuu         0.792   0.895  1.0
#
#        Loudness  Speechiness  Acousticness  Instrumentalness  Liveness  \
# Index
# 12749    -5.260       0.0505         0.240            0.0000    0.1260
# 1517     -5.260       0.0505         0.240            0.0000    0.1260
# 6666     -8.762       0.0392         0.536            0.0106    0.9020
# 4210     -8.762       0.0392         0.536            0.0106    0.9020
# 12003    -3.112       0.0587         0.165            0.0000    0.0501
#
#        Valence    Tempo  Duration_ms       Stream
# Index
# 12749    0.690  126.556     206495.0   26314102.0
# 1517     0.690  126.556     206495.0   26314102.0
# 6666     0.454  115.724     198133.0    8753204.0
# 4210     0.454  115.724     198133.0    8753204.0
# 12003    0.793   94.968     201526.0  589683929.0

# %%
df_clean = df_clean.drop_duplicates(subset=dup_cols, keep="first")
df_clean.duplicated(subset=dup_cols).sum()
# Out:
# 0

# %% [markdown]
# ### 3. Parsing Errors

# %% [markdown]
# By doing a dive into the actual csv file, Ive found several things
# Since some artist and album names have the charatcer `$`, this causes errors in matplotlib plotting. So I will fix the parsing by escaping any `$` in the Artist, Album or Track Column

# %%
for col in ["Artist", "Album", "Track"]:
    df_clean.loc[:, col] = df_clean[col].str.replace("$", r"\$", regex=False)

# %% [markdown]
# ### 4. Removing Non-Musical Artists

# %% [markdown]
# Some artists in the dataset primarily produce non-musical audio (such as sleep or ambient noise), which results in auditory feature values that do not accurately represent musical characteristics. Since these observations distort the distributions of key features and are not aligned with the goals of this analysis, I will remove them to improve the quality of my data analysis.

# %%
#First, creating a mask to pick out sleep/ambient artists
keywords = ["Ocean", "Sleep", "Noise", "Sound", "Sounds"]

mask = df_clean["Artist"].str.contains(
    "|".join(keywords),
    case=False,
    na=False
)

df_clean.loc[mask, "Artist"].unique()
# Out:
# array(['SEGA SOUND TEAM', 'Ocean Sounds', 'Ocean Waves For Sleep',
#        'Sleeping At Last', 'Soundgarden', 'Frank Ocean',
#        'White Noise for Babies', 'White Noise Baby Sleep', 'Danny Ocean',
#        'Sleepy Hallow', 'Rain Fruits Sounds', 'Sleepy Penguin'],
#       dtype=object)

# %%
#Removing Artists that create sleep/ambient noise, after checking each of these artists on Spotify
artists_to_remove = [
    "Ocean Sounds", "Ocean Waves For Sleep", "White Noise for Babies", "White Noise Baby Sleep",
    "FIFA Sound", "Rain Fruits Sounds", "Sleepy Penguin" 
]

keep_mask = df_clean["Artist"].isin(artists_to_remove) == False
df_clean = df_clean[keep_mask]

# %% [markdown]
# ## The New Dataset

# %% [markdown]
# Now lets get an understanding of our new refined dataset

# %%
COLS_df = pd.DataFrame({
    "column": df_clean.columns,
    "dtype": df_clean.dtypes.values,
    "unique_values": df_clean.nunique().values,
    "missing_values": df_clean.isnull().sum()
})
COLS_df.set_index("column",inplace=True)

COLS_df
# Out:
#                     dtype  unique_values  missing_values
# column
# Artist             object           2042               0
# Url_spotify        object           2042               0
# Track              object          17280               0
# Album              object          11625               0
# Album_type         object              3               0
# Uri                object          18270               0
# Danceability      float64            889               0
# Energy            float64           1252               0
# Key               float64             12               0
# Loudness          float64           9211               0
# Speechiness       float64           1267               0
# Acousticness      float64           3102               0
# Instrumentalness  float64           3943               0
# Liveness          float64           1530               0
# Valence           float64           1278               0
# Tempo             float64          14593               0
# Duration_ms       float64          14323               0
# Stream            float64          18412               0

# %% [markdown]
# ### Export new dataset

# %% [markdown]
# With a set of features now relevant to our analysis goals, purified entries (real music, no ambience noise), machine-readable characters, and no more null values, we can now create our refined dataset!

# %%
df_clean.to_csv("Datasets/music_refined.csv", index=True)
